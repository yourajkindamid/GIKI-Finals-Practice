# %%
import pandas as pd
import numpy as np
data = {'car' : [np.nan,"Volvo", "Ford"], 'new car': ["Volvo", "Mustang", "Honda"]}



clean  = pd.Series(data)
print(clean)
ordered = pd.DataFrame(data,index = [1, 2, 3])
#ordered=ordered.fillna("BMW")
print(ordered)

ordered.isna()
# Out:
# car             [nan, Volvo, Ford]
# new car    [Volvo, Mustang, Honda]
# dtype: object
#      car  new car
# 1    NaN    Volvo
# 2  Volvo  Mustang
# 3   Ford    Honda
#      car  new car
# 1   True    False
# 2  False    False
# 3  False    False

# %%
a = np.array([(1, 2, 3), (3, 2, 4)])
h = a.reshape(3,2)
print(h)
# Out:
# [[1 2]
#  [3 3]
#  [2 4]]

# %%
print(h[0:2, 1])
# Out:
# [2 3]

# %%
h.sum(axis=0)
# Out:
# array([6, 9])

# %%
print(a+a)
# Out:
# [[2 4 6]
#  [6 4 8]]

# %%
ordered[['car', 'new car']]
# Out:
#      car  new car
# 1    BMW    Volvo
# 2  Volvo  Mustang
# 3   Ford    Honda

# %%
ordered.loc[[1, 2, 3]]
# Out:
#      car  new car
# 1    BMW    Volvo
# 2  Volvo  Mustang
# 3   Ford    Honda
