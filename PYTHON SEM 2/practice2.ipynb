# %%
#Question 1
c1 = 5 + 3j
c2 = -2 + 4j
print(c1 + c2, type(c1+c2))
print(c1 - c2, type(c1-c2))
print(c1 * c2, type(c1*c2))
print(c1 / c2, type(c1/c2))
c1 is c2
# Out:
# (3+7j) <class 'complex'>
# (7-1j) <class 'complex'>
# (-22+14j) <class 'complex'>
# (0.1-1.3j) <class 'complex'>
# False

# %%
#Question 2
s1 = "He said, \"Python's escape sequences are powerful!\""
print(s1)
s2 = "C:\\Users\\Documents\\Python\\Lab1"
print(s2)
s3 = '''\tThis is string
        which is covering a 
        lot of unnecessary space'''
print(s3)
print(s1 + s2 +s3)
# Out:
# He said, "Python's escape sequences are powerful!"
# C:\Users\Documents\Python\Lab1
# 	This is string
#         which is covering a
#         lot of unnecessary space
# He said, "Python's escape sequences are powerful!"C:\Users\Documents\Python\Lab1	This is string
#         which is covering a
#         lot of unnecessary space

# %%
#Question 3
x = 1000
y = 1000
print(x is y)
y = 500
print(x is y)
lst1 = [1, 2, 3]
lst2 = lst1
lst1[0] = 100
print(lst1)
print(lst2)
# Out:
# False
# False
# [100, 2, 3]
# [100, 2, 3]
