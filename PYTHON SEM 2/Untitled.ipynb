# %%
names_scores = [('ali', 28), ('khan', 20), ('salim', 21), ('farhan', 19), ('zouqan', 11)]
def process_scores(names_scores):
    only_scores = list(map(lambda x: x[1], names_scores))
    score_total = 0
    count = 0
    for names, x in names_scores:
        score_total += x
        count += 1
    average = score_total / count
    sorted_std = sorted(names_scores, key=lambda x: x[1], reverse=True) #learned sorted function from w3schools as i could not think of another way
    top_3 = sorted_std[:3]
    return top_3, average
print(process_scores(names_scores))
# Out:
# ([('ali', 28), ('salim', 21), ('khan', 20)], 19.8)
